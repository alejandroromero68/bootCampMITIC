# %% [markdown]
# ## Análisis de Datos con Pandas y JSON (Opcional)
#
# Instrucciones
#
# Preparación del Entorno
#
# Asegúrate de tener instalado Pandas en tu entorno de trabajo.
#
# Instala la biblioteca requests para realizar solicitudes HTTP.

# %%
import pandas as pd
import requests

api_key='c040673e91a72ec187de0e7aa6f6e2cd'
#city = "New York"
#url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
 
 
city = 'London'
url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"


 # Realizar la solicitud HTTP
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Cargar los datos JSON en un diccionario
    data = response.json()
    
# Cargar los datos en un DataFrame
    df = pd.json_normalize(data['list'])

    # Mostrar las primeras 10 filas del DataFrame
    print(df.head(12))
else:
    print("Error en la solicitud:", response.status_code, response.text)
# Out:
#             dt                                            weather  visibility  \
# 0   1728745200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1   1728756000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2   1728766800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 3   1728777600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4   1728788400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1728799200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1728810000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1728820800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 8   1728831600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 9   1728842400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 10  1728853200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 11  1728864000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
#
#     pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 0   1.0  2024-10-12 15:00:00      14.22            13.86          12.49
# 1   1.0  2024-10-12 18:00:00      12.52            11.81          11.23
# 2   0.0  2024-10-12 21:00:00       8.91             5.78           8.91
# 3   0.0  2024-10-13 00:00:00       7.74             4.37           7.74
# 4   0.0  2024-10-13 03:00:00       7.08             4.08           7.08
# 5   0.0  2024-10-13 06:00:00       6.54             3.87           6.54
# 6   0.0  2024-10-13 09:00:00       8.10             6.06           8.10
# 7   0.0  2024-10-13 12:00:00       9.99             8.94           9.99
# 8   0.0  2024-10-13 15:00:00      10.32             8.74          10.32
# 9   0.0  2024-10-13 18:00:00       9.70             9.70           9.70
# 10  0.0  2024-10-13 21:00:00       9.19             8.61           9.19
# 11  0.0  2024-10-14 00:00:00       8.83             8.45           8.83
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 0           14.22           1006            1006             1000
# 1           12.52           1007            1007             1002
# 2            8.91           1010            1010             1006
# 3            7.74           1012            1012             1008
# 4            7.08           1015            1015             1010
# 5            6.54           1017            1017             1013
# 6            8.10           1020            1020             1016
# 7            9.99           1021            1021             1016
# 8           10.32           1020            1020             1016
# 9            9.70           1019            1019             1015
# 10           9.19           1020            1020             1015
# 11           8.83           1019            1019             1015
#
#     main.humidity  main.temp_kf  clouds.all  wind.speed  wind.deg  wind.gust  \
# 0              83          1.73          60        3.83       233       9.08
# 1              76          1.29          61        5.23       284      11.13
# 2              68          0.00          11        6.23       283      13.07
# 3              66          0.00          46        6.00       283      13.19
# 4              62          0.00         100        4.69       283      11.65
# 5              65          0.00         100        3.79       277      10.02
# 6              60          0.00         100        3.28       279       5.85
# 7              53          0.00         100        2.32       308       3.92
# 8              51          0.00         100        0.90       279       1.16
# 9              55          0.00         100        1.29       111       1.55
# 10             62          0.00         100        1.61       133       2.80
# 11             65          0.00         100        1.38       127       2.54
#
#     rain.3h sys.pod
# 0      0.87       d
# 1      0.19       n
# 2       NaN       n
# 3       NaN       n
# 4       NaN       n
# 5       NaN       n
# 6       NaN       d
# 7       NaN       d
# 8       NaN       d
# 9       NaN       n
# 10      NaN       n
# 11      NaN       n

# %% [markdown]
# ## Exploración Inicial de los Datos
#
# Muestra las últimas 5 filas del DataFrame.
#
# Utiliza el método info() para obtener información general sobre el DataFrame, incluyendo el número de entradas, nombres de las columnas, tipos de datos y memoria utilizada.
#
# Genera estadísticas descriptivas del DataFrame utilizando el método describe().

# %%
print(df.tail(5))
# Out:
#             dt                                            weather  visibility  \
# 35  1729123200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 36  1729134000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 37  1729144800  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 38  1729155600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 39  1729166400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
#
#      pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 35  1.00  2024-10-17 00:00:00      16.90            17.07          16.90
# 36  0.97  2024-10-17 03:00:00      17.22            17.37          17.22
# 37  0.54  2024-10-17 06:00:00      16.46            16.56          16.46
# 38  0.00  2024-10-17 09:00:00      16.72            16.67          16.72
# 39  0.00  2024-10-17 12:00:00      17.51            17.20          17.51
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 35          16.90           1005            1005             1001
# 36          17.22           1006            1006             1002
# 37          16.46           1008            1008             1004
# 38          16.72           1011            1011             1007
# 39          17.51           1013            1013             1008
#
#     main.humidity  main.temp_kf  clouds.all  wind.speed  wind.deg  wind.gust  \
# 35             93           0.0         100        4.09       157      12.19
# 36             91           0.0         100        5.12       177      10.95
# 37             92           0.0         100        4.04       197       9.13
# 38             85           0.0         100        3.24       230       6.59
# 39             72           0.0         100        3.42       240       5.17
#
#     rain.3h sys.pod
# 35     0.30       n
# 36     0.52       n
# 37     0.10       n
# 38      NaN       d
# 39      NaN       d

# %% [markdown]
# Utilizar el método info() para obtener información general sobre el DataFrame:

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dt               40 non-null     int64
#  1   weather          40 non-null     object
#  2   visibility       40 non-null     int64
#  3   pop              40 non-null     float64
#  4   dt_txt           40 non-null     object
#  5   main.temp        40 non-null     float64
#  6   main.feels_like  40 non-null     float64
#  7   main.temp_min    40 non-null     float64
#  8   main.temp_max    40 non-null     float64
#  9   main.pressure    40 non-null     int64
#  10  main.sea_level   40 non-null     int64
#  11  main.grnd_level  40 non-null     int64
#  12  main.humidity    40 non-null     int64
#  13  main.temp_kf     40 non-null     float64
#  14  clouds.all       40 non-null     int64
#  15  wind.speed       40 non-null     float64
#  16  wind.deg         40 non-null     int64
#  17  wind.gust        40 non-null     float64
#  18  rain.3h          9 non-null      float64
#  19  sys.pod          40 non-null     object
# dtypes: float64(9), int64(8), object(3)
# memory usage: 6.4+ KB
# None

# %% [markdown]
# Generar estadísticas descriptivas del DataFrame utilizando el método describe():

# %%
print(df.describe())
# Out:
#                  dt  visibility        pop  main.temp  main.feels_like  \
# count  4.000000e+01        40.0  40.000000  40.000000        40.000000
# mean   1.728956e+09     10000.0   0.194750  12.959000        12.232250
# std    1.262569e+05         0.0   0.374536   3.665329         4.355414
# min    1.728745e+09     10000.0   0.000000   6.540000         3.870000
# 25%    1.728850e+09     10000.0   0.000000   9.622500         8.707500
# 50%    1.728956e+09     10000.0   0.000000  12.575000        11.885000
# 75%    1.729061e+09     10000.0   0.057500  16.552500        16.565000
# max    1.729166e+09     10000.0   1.000000  20.660000        20.530000
#
#        main.temp_min  main.temp_max  main.pressure  main.sea_level  \
# count      40.000000      40.000000      40.000000       40.000000
# mean       12.883500      12.959000    1013.450000     1013.450000
# std         3.669519       3.665329       6.038127        6.038127
# min         6.540000       6.540000    1004.000000     1004.000000
# 25%         9.622500       9.622500    1007.000000     1007.000000
# 50%        12.305000      12.575000    1014.000000     1014.000000
# 75%        16.552500      16.552500    1019.250000     1019.250000
# max        20.660000      20.660000    1021.000000     1021.000000
#
#        main.grnd_level  main.humidity  main.temp_kf  clouds.all  wind.speed  \
# count         40.00000      40.000000     40.000000   40.000000   40.000000
# mean        1009.10000      75.375000      0.075500   93.925000    3.426750
# std            6.12184      11.258473      0.336992   17.957767    1.413092
# min         1000.00000      51.000000      0.000000   11.000000    0.900000
# 25%         1002.00000      66.750000      0.000000   99.000000    2.220000
# 50%         1009.50000      77.500000      0.000000  100.000000    3.405000
# 75%         1015.00000      83.250000      0.000000  100.000000    4.397500
# max         1017.00000      93.000000      1.730000  100.000000    6.230000
#
#          wind.deg  wind.gust   rain.3h
# count   40.000000  40.000000  9.000000
# mean   166.725000   8.056250  0.455556
# std     70.532767   3.715558  0.298208
# min     76.000000   1.160000  0.100000
# 25%    111.000000   4.982500  0.260000
# 50%    130.000000   9.105000  0.300000
# 75%    230.750000  11.255000  0.720000
# max    308.000000  13.190000  0.870000

# %%
import pandas as pd
import requests

# Paso 2: Obtener los Datos
api_key='c040673e91a72ec187de0e7aa6f6e2cd'
url = f'http://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}&units=metric'
response = requests.get(url)
data = response.json()

# Crear un DataFrame a partir de los datos JSON
df = pd.json_normalize(data)

# %%
import pandas as pd
import requests

# Paso 2: Obtener los Datos
api_key='c040673e91a72ec187de0e7aa6f6e2cd'
url = f'http://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}&units=metric'
response = requests.get(url)
data = response.json()

# Crear un DataFrame a partir de los datos JSON
df = pd.json_normalize(data)


print("Primeras 10 filas del DataFrame:")
print(df.head(10))

# Paso 3: Exploración Inicial de los Datos
print("nÚltimas 5 filas del DataFrame:")
print(df.tail(5))

print("nInformación del DataFrame:")
print(df.info())

print("nEstadísticas descriptivas del DataFrame:")
print(df.describe())

# Paso 4: Inspección de los Datos
print("nTipos de datos de las columnas:")
print(df.dtypes)

print("nConteo de valores únicos en la columna 'weather.main':")
print(df['weather'][0][0]['main'])

print("nValores únicos en la columna 'name':")
print(df['name'].unique())

# Paso 5: Filtrado de Datos
df['main.temp'] = df['main.temp'].astype(float)
df['main.humidity'] = df['main.humidity'].astype(float)

temp_mayor_20 = df[df['main.temp'] > 20]
print("nFilas donde la temperatura es mayor a 20 grados Celsius:")
print(temp_mayor_20)

humedad_menor_50 = df[df['main.humidity'] < 50]
print("nFilas donde la humedad es menor a 50%:")
print(humedad_menor_50)

query_result = df.query('name == "London" & main.temp < 15')
print("nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
print(query_result)

# Paso 6: Slicing de Datos
city_temp = df[['name', 'main.temp']]
print("nColumnas 'city' y 'temp':")
print(city_temp)

loc_result = df.loc[5:10, ['name', 'weather']]
print("nFilas 5 a 10 y columnas 'name' y 'weather' usando loc:")
print(loc_result)

iloc_result = df.iloc[0:5, 0:3]
print("nPrimeras 5 filas y primeras 3 columnas usando iloc:")
print(iloc_result)
# Out:
# Primeras 10 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]
# nÚltimas 5 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]
# nInformación del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   weather          1 non-null      object
#  1   base             1 non-null      object
#  2   visibility       1 non-null      int64
#  3   dt               1 non-null      int64
#  4   timezone         1 non-null      int64
#  5   id               1 non-null      int64
#  6   name             1 non-null      object
#  7   cod              1 non-null      int64
#  8   coord.lon        1 non-null      float64
#  9   coord.lat        1 non-null      float64
#  10  main.temp        1 non-null      float64
#  11  main.feels_like  1 non-null      float64
#  12  main.temp_min    1 non-null      float64
#  13  main.temp_max    1 non-null      float64
#  14  main.pressure    1 non-null      int64
#  15  main.humidity    1 non-null      int64
#  16  main.sea_level   1 non-null      int64
#  17  main.grnd_level  1 non-null      int64
#  18  wind.speed       1 non-null      float64
#  19  wind.deg         1 non-null      int64
#  20  clouds.all       1 non-null      int64
#  21  sys.type         1 non-null      int64
#  22  sys.id           1 non-null      int64
#  23  sys.country      1 non-null      object
#  24  sys.sunrise      1 non-null      int64
#  25  sys.sunset       1 non-null      int64
# dtypes: float64(7), int64(15), object(4)
# memory usage: 340.0+ bytes
# None
# nEstadísticas descriptivas del DataFrame:
#        visibility            dt  timezone         id    cod  coord.lon  \
# count         1.0  1.000000e+00       1.0        1.0    1.0     1.0000
# mean      10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# std           NaN           NaN       NaN        NaN    NaN        NaN
# min       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 25%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 50%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 75%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# max       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
#
#        coord.lat  main.temp  main.feels_like  main.temp_min  ...  \
# count     1.0000       1.00             1.00           1.00  ...
# mean     51.5085      14.97            14.64          14.32  ...
# std          NaN        NaN              NaN            NaN  ...
# min      51.5085      14.97            14.64          14.32  ...
# 25%      51.5085      14.97            14.64          14.32  ...
# 50%      51.5085      14.97            14.64          14.32  ...
# 75%      51.5085      14.97            14.64          14.32  ...
# max      51.5085      14.97            14.64          14.32  ...
#
#        main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# count            1.0             1.0              1.0        1.00       1.0
# mean            81.0          1006.0           1001.0        5.14     210.0
# std              NaN             NaN              NaN         NaN       NaN
# min             81.0          1006.0           1001.0        5.14     210.0
# 25%             81.0          1006.0           1001.0        5.14     210.0
# 50%             81.0          1006.0           1001.0        5.14     210.0
# 75%             81.0          1006.0           1001.0        5.14     210.0
# max             81.0          1006.0           1001.0        5.14     210.0
#
#        clouds.all  sys.type     sys.id   sys.sunrise    sys.sunset
# count         1.0       1.0        1.0  1.000000e+00  1.000000e+00
# mean         75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# std           NaN       NaN        NaN           NaN           NaN
# min          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 25%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 50%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 75%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# max          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
#
# [8 rows x 22 columns]
# nTipos de datos de las columnas:
# weather             object
# base                object
# visibility           int64
# dt                   int64
# timezone             int64
# id                   int64
# name                object
# cod                  int64
# coord.lon          float64
# coord.lat          float64
# main.temp          float64
# main.feels_like    float64
# main.temp_min      float64
# main.temp_max      float64
# main.pressure        int64
# main.humidity        int64
# main.sea_level       int64
# main.grnd_level      int64
# wind.speed         float64
# wind.deg             int64
# clouds.all           int64
# sys.type             int64
# sys.id               int64
# sys.country         object
# sys.sunrise          int64
# sys.sunset           int64
# dtype: object
# nConteo de valores únicos en la columna 'weather.main':
# Clouds
# nValores únicos en la columna 'name':
# ['London']
# nFilas donde la temperatura es mayor a 20 grados Celsius:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# nFilas donde la humedad es menor a 50%:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'main'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[2], line 47
#      44 print("nFilas donde la humedad es menor a 50%:")
#      45 print(humedad_menor_50)
# ---> 47 query_result = df.query('name == "London" & main.temp < 15')
#      48 print("nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
#      49 print(query_result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:644, in BaseExprVisitor.visit_Attribute(self, node, **kwargs)
#     641 ctx = node.ctx
#     642 if isinstance(ctx, ast.Load):
#     643     # resolve the value
# --> 644     resolved = self.visit(value).value
#     645     try:
#     646         v = getattr(resolved, attr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'main' is not defined

# %%
print(df.columns)
# Out:
# Index(['weather', 'base', 'visibility', 'dt', 'timezone', 'id', 'name', 'cod',
#        'coord.lon', 'coord.lat', 'main.temp', 'main.feels_like',
#        'main.temp_min', 'main.temp_max', 'main.pressure', 'main.humidity',
#        'main.sea_level', 'main.grnd_level', 'wind.speed', 'wind.deg',
#        'clouds.all', 'sys.type', 'sys.id', 'sys.country', 'sys.sunrise',
#        'sys.sunset'],
#       dtype='object')

# %%
print(df.head())
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Paso a paso

# %%
import pandas as pd
import requests

# Paso 2: Obtener los Datos
api_key='c040673e91a72ec187de0e7aa6f6e2cd'
url = f'http://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}&units=metric'
response = requests.get(url)
data = response.json()
# Out:
# Primeras 10 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]
# nÚltimas 5 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]
# nInformación del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   weather          1 non-null      object
#  1   base             1 non-null      object
#  2   visibility       1 non-null      int64
#  3   dt               1 non-null      int64
#  4   timezone         1 non-null      int64
#  5   id               1 non-null      int64
#  6   name             1 non-null      object
#  7   cod              1 non-null      int64
#  8   coord.lon        1 non-null      float64
#  9   coord.lat        1 non-null      float64
#  10  main.temp        1 non-null      float64
#  11  main.feels_like  1 non-null      float64
#  12  main.temp_min    1 non-null      float64
#  13  main.temp_max    1 non-null      float64
#  14  main.pressure    1 non-null      int64
#  15  main.humidity    1 non-null      int64
#  16  main.sea_level   1 non-null      int64
#  17  main.grnd_level  1 non-null      int64
#  18  wind.speed       1 non-null      float64
#  19  wind.deg         1 non-null      int64
#  20  clouds.all       1 non-null      int64
#  21  sys.type         1 non-null      int64
#  22  sys.id           1 non-null      int64
#  23  sys.country      1 non-null      object
#  24  sys.sunrise      1 non-null      int64
#  25  sys.sunset       1 non-null      int64
# dtypes: float64(7), int64(15), object(4)
# memory usage: 340.0+ bytes
# None
# nEstadísticas descriptivas del DataFrame:
#        visibility            dt  timezone         id    cod  coord.lon  \
# count         1.0  1.000000e+00       1.0        1.0    1.0     1.0000
# mean      10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# std           NaN           NaN       NaN        NaN    NaN        NaN
# min       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 25%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 50%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 75%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# max       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
#
#        coord.lat  main.temp  main.feels_like  main.temp_min  ...  \
# count     1.0000       1.00             1.00           1.00  ...
# mean     51.5085      14.97            14.64          14.32  ...
# std          NaN        NaN              NaN            NaN  ...
# min      51.5085      14.97            14.64          14.32  ...
# 25%      51.5085      14.97            14.64          14.32  ...
# 50%      51.5085      14.97            14.64          14.32  ...
# 75%      51.5085      14.97            14.64          14.32  ...
# max      51.5085      14.97            14.64          14.32  ...
#
#        main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# count            1.0             1.0              1.0        1.00       1.0
# mean            81.0          1006.0           1001.0        5.14     210.0
# std              NaN             NaN              NaN         NaN       NaN
# min             81.0          1006.0           1001.0        5.14     210.0
# 25%             81.0          1006.0           1001.0        5.14     210.0
# 50%             81.0          1006.0           1001.0        5.14     210.0
# 75%             81.0          1006.0           1001.0        5.14     210.0
# max             81.0          1006.0           1001.0        5.14     210.0
#
#        clouds.all  sys.type     sys.id   sys.sunrise    sys.sunset
# count         1.0       1.0        1.0  1.000000e+00  1.000000e+00
# mean         75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# std           NaN       NaN        NaN           NaN           NaN
# min          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 25%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 50%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 75%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# max          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
#
# [8 rows x 22 columns]
# nTipos de datos de las columnas:
# weather             object
# base                object
# visibility           int64
# dt                   int64
# timezone             int64
# id                   int64
# name                object
# cod                  int64
# coord.lon          float64
# coord.lat          float64
# main.temp          float64
# main.feels_like    float64
# main.temp_min      float64
# main.temp_max      float64
# main.pressure        int64
# main.humidity        int64
# main.sea_level       int64
# main.grnd_level      int64
# wind.speed         float64
# wind.deg             int64
# clouds.all           int64
# sys.type             int64
# sys.id               int64
# sys.country         object
# sys.sunrise          int64
# sys.sunset           int64
# dtype: object
# nConteo de valores únicos en la columna 'weather.main':
# Clouds
# nValores únicos en la columna 'name':
# ['London']
# nFilas donde la temperatura es mayor a 20 grados Celsius:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# nFilas donde la humedad es menor a 50%:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'main'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[5], line 47
#      44 print("nFilas donde la humedad es menor a 50%:")
#      45 print(humedad_menor_50)
# ---> 47 query_result = df.query('name == "London" & main.temp < 15')
#      48 print("nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
#      49 print(query_result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:644, in BaseExprVisitor.visit_Attribute(self, node, **kwargs)
#     641 ctx = node.ctx
#     642 if isinstance(ctx, ast.Load):
#     643     # resolve the value
# --> 644     resolved = self.visit(value).value
#     645     try:
#     646         v = getattr(resolved, attr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'main' is not defined

# %%
# Crear un DataFrame a partir de los datos JSON
df = pd.json_normalize(data)
print("Primeras 10 filas del DataFrame:")
print(df.head(10))
# Out:
# Primeras 10 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]

# %%
# Paso 3: Exploración Inicial de los Datos
print("nÚltimas 5 filas del DataFrame:")
print(df.tail(5))

print("nInformación del DataFrame:")
print(df.info())

print("nEstadísticas descriptivas del DataFrame:")
print(df.describe())
# Out:
# nÚltimas 5 filas del DataFrame:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1728738370      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1006             1001        5.14       210          75
#
#    sys.type   sys.id  sys.country  sys.sunrise  sys.sunset
# 0         2  2075535           GB   1728713982  1728753226
#
# [1 rows x 26 columns]
# nInformación del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   weather          1 non-null      object
#  1   base             1 non-null      object
#  2   visibility       1 non-null      int64
#  3   dt               1 non-null      int64
#  4   timezone         1 non-null      int64
#  5   id               1 non-null      int64
#  6   name             1 non-null      object
#  7   cod              1 non-null      int64
#  8   coord.lon        1 non-null      float64
#  9   coord.lat        1 non-null      float64
#  10  main.temp        1 non-null      float64
#  11  main.feels_like  1 non-null      float64
#  12  main.temp_min    1 non-null      float64
#  13  main.temp_max    1 non-null      float64
#  14  main.pressure    1 non-null      int64
#  15  main.humidity    1 non-null      int64
#  16  main.sea_level   1 non-null      int64
#  17  main.grnd_level  1 non-null      int64
#  18  wind.speed       1 non-null      float64
#  19  wind.deg         1 non-null      int64
#  20  clouds.all       1 non-null      int64
#  21  sys.type         1 non-null      int64
#  22  sys.id           1 non-null      int64
#  23  sys.country      1 non-null      object
#  24  sys.sunrise      1 non-null      int64
#  25  sys.sunset       1 non-null      int64
# dtypes: float64(7), int64(15), object(4)
# memory usage: 340.0+ bytes
# None
# nEstadísticas descriptivas del DataFrame:
#        visibility            dt  timezone         id    cod  coord.lon  \
# count         1.0  1.000000e+00       1.0        1.0    1.0     1.0000
# mean      10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# std           NaN           NaN       NaN        NaN    NaN        NaN
# min       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 25%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 50%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# 75%       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
# max       10000.0  1.728738e+09    3600.0  2643743.0  200.0    -0.1257
#
#        coord.lat  main.temp  main.feels_like  main.temp_min  ...  \
# count     1.0000       1.00             1.00           1.00  ...
# mean     51.5085      14.97            14.64          14.32  ...
# std          NaN        NaN              NaN            NaN  ...
# min      51.5085      14.97            14.64          14.32  ...
# 25%      51.5085      14.97            14.64          14.32  ...
# 50%      51.5085      14.97            14.64          14.32  ...
# 75%      51.5085      14.97            14.64          14.32  ...
# max      51.5085      14.97            14.64          14.32  ...
#
#        main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# count            1.0             1.0              1.0        1.00       1.0
# mean            81.0          1006.0           1001.0        5.14     210.0
# std              NaN             NaN              NaN         NaN       NaN
# min             81.0          1006.0           1001.0        5.14     210.0
# 25%             81.0          1006.0           1001.0        5.14     210.0
# 50%             81.0          1006.0           1001.0        5.14     210.0
# 75%             81.0          1006.0           1001.0        5.14     210.0
# max             81.0          1006.0           1001.0        5.14     210.0
#
#        clouds.all  sys.type     sys.id   sys.sunrise    sys.sunset
# count         1.0       1.0        1.0  1.000000e+00  1.000000e+00
# mean         75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# std           NaN       NaN        NaN           NaN           NaN
# min          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 25%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 50%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# 75%          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
# max          75.0       2.0  2075535.0  1.728714e+09  1.728753e+09
#
# [8 rows x 22 columns]

# %%
# Paso 4: Inspección de los Datos
print("nTipos de datos de las columnas:")
print(df.dtypes)

print("nConteo de valores únicos en la columna 'weather.main':")
print(df['weather'][0][0]['main'])

print("nValores únicos en la columna 'name':")
print(df['name'].unique())
# Out:
# nTipos de datos de las columnas:
# weather             object
# base                object
# visibility           int64
# dt                   int64
# timezone             int64
# id                   int64
# name                object
# cod                  int64
# coord.lon          float64
# coord.lat          float64
# main.temp          float64
# main.feels_like    float64
# main.temp_min      float64
# main.temp_max      float64
# main.pressure        int64
# main.humidity        int64
# main.sea_level       int64
# main.grnd_level      int64
# wind.speed         float64
# wind.deg             int64
# clouds.all           int64
# sys.type             int64
# sys.id               int64
# sys.country         object
# sys.sunrise          int64
# sys.sunset           int64
# dtype: object
# nConteo de valores únicos en la columna 'weather.main':
# Clouds
# nValores únicos en la columna 'name':
# ['London']

# %%
print(df.columns)
# Paso 5: Filtrado de Datos
df['main.temp'] = df['main.temp'].astype(float)
df['main.humidity'] = df['main.humidity'].astype(float)
temp_mayor_20 = df[df['main.temp'] > 20]
print("nFilas donde la temperatura es mayor a 20 grados Celsius:")
print(temp_mayor_20)
# Out:
# Index(['weather', 'base', 'visibility', 'dt', 'timezone', 'id', 'name', 'cod',
#        'coord.lon', 'coord.lat', 'main.temp', 'main.feels_like',
#        'main.temp_min', 'main.temp_max', 'main.pressure', 'main.humidity',
#        'main.sea_level', 'main.grnd_level', 'wind.speed', 'wind.deg',
#        'clouds.all', 'sys.type', 'sys.id', 'sys.country', 'sys.sunrise',
#        'sys.sunset'],
#       dtype='object')
# nFilas donde la temperatura es mayor a 20 grados Celsius:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Paso 5: Filtrado de Datos
df['main.temp'] = df['main.temp'].astype(float)
df['main.humidity'] = df['main.humidity'].astype(float)

temp_mayor_20 = df[df['main.temp'] > 20]
print("nFilas donde la temperatura es mayor a 20 grados Celsius:")
print(temp_mayor_20)

humedad_menor_50 = df[df['main.humidity'] < 50]
print("nFilas donde la humedad es menor a 50%:")
print(humedad_menor_50)

query_result = df.query('name == "London" & main.temp < 15')
print("nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
print(query_result)
# Out:
# nFilas donde la temperatura es mayor a 20 grados Celsius:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# nFilas donde la humedad es menor a 50%:
# Empty DataFrame
# Columns: [weather, base, visibility, dt, timezone, id, name, cod, coord.lon, coord.lat, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.humidity, main.sea_level, main.grnd_level, wind.speed, wind.deg, clouds.all, sys.type, sys.id, sys.country, sys.sunrise, sys.sunset]
# Index: []
#
# [0 rows x 26 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'main'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[16], line 13
#      10 print("nFilas donde la humedad es menor a 50%:")
#      11 print(humedad_menor_50)
# ---> 13 query_result = df.query('name == "London" & main.temp < 15')
#      14 print("nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
#      15 print(query_result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:644, in BaseExprVisitor.visit_Attribute(self, node, **kwargs)
#     641 ctx = node.ctx
#     642 if isinstance(ctx, ast.Load):
#     643     # resolve the value
# --> 644     resolved = self.visit(value).value
#     645     try:
#     646         v = getattr(resolved, attr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'main' is not defined

# %%
import pandas as pd
import requests

api_key = 'c040673e91a72ec187de0e7aa6f6e2cd'
city = 'London'
url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"

# Realizar la solicitud HTTP
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Cargar los datos JSON en un diccionario
    data = response.json()
    
    # Cargar los datos en un DataFrame
    df = pd.json_normalize(data['list'])

    # Ver las columnas disponibles
    print("Columnas del DataFrame:", df.columns)

    # Paso 5: Filtrado de Datos
    # Convertir las columnas de temperatura y humedad a tipo float
    df['main.temp'] = df['main.temp'].astype(float)
    df['main.humidity'] = df['main.humidity'].astype(float)

    # Filtrar donde la temperatura es mayor a 20 grados Celsius
    temp_mayor_20 = df[df['main.temp'] > 20]
    print("Filas donde la temperatura es mayor a 20 grados Celsius:")
    print(temp_mayor_20)

    # Filtrar donde la humedad es menor a 50%
    humedad_menor_50 = df[df['main.humidity'] < 50]
    print("Filas donde la humedad es menor a 50%:")
    print(humedad_menor_50)

    # Filtrar usando query
    query_result = df.query('name == "London" & `main.temp` < 15')
    print("Filas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
    print(query_result)
else:
    print("Error en la solicitud:", response.status_code, response.text)
# Out:
# Columnas del DataFrame: Index(['dt', 'weather', 'visibility', 'pop', 'dt_txt', 'main.temp',
#        'main.feels_like', 'main.temp_min', 'main.temp_max', 'main.pressure',
#        'main.sea_level', 'main.grnd_level', 'main.humidity', 'main.temp_kf',
#        'clouds.all', 'wind.speed', 'wind.deg', 'wind.gust', 'rain.3h',
#        'sys.pod'],
#       dtype='object')
# Filas donde la temperatura es mayor a 20 grados Celsius:
#             dt                                            weather  visibility  \
# 31  1729080000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
#
#     pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 31  0.0  2024-10-16 12:00:00      20.66            20.53          20.66
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 31          20.66           1004            1004             1000
#
#     main.humidity  main.temp_kf  clouds.all  wind.speed  wind.deg  wind.gust  \
# 31           67.0           0.0          93        5.36       176      10.85
#
#     rain.3h sys.pod
# 31      NaN       d
# Filas donde la humedad es menor a 50%:
# Empty DataFrame
# Columns: [dt, weather, visibility, pop, dt_txt, main.temp, main.feels_like, main.temp_min, main.temp_max, main.pressure, main.sea_level, main.grnd_level, main.humidity, main.temp_kf, clouds.all, wind.speed, wind.deg, wind.gust, rain.3h, sys.pod]
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[19], line 38
#      35 print(humedad_menor_50)
#      37 # Filtrar usando query
# ---> 38 query_result = df.query('name == "London" & `main.temp` < 15')
#      39 print("Filas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
#      40 print(query_result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:739, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
# --> 739     lhs = self._try_visit_binop(x)
#     740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'name' is not defined

# %%
import pandas as pd
import requests

api_key = 'c040673e91a72ec187de0e7aa6f6e2cd'
city = 'London'
url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"

# Realizar la solicitud HTTP
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Cargar los datos JSON en un diccionario
    data = response.json()
    
    # Cargar los datos en un DataFrame
    df = pd.json_normalize(data['list'])

    # Mostrar las últimas 5 filas del DataFrame
    print("Últimas 5 filas del DataFrame:")
    print(df.tail(5))

    # Mostrar información general del DataFrame
    print("\nInformación del DataFrame:")
    print(df.info())

    # Generar estadísticas descriptivas
    print("\nEstadísticas descriptivas del DataFrame:")
    print(df.describe())

    # Paso 5: Filtrado de Datos
    # Convertir las columnas de temperatura y humedad a tipo float
    df['main.temp'] = df['main.temp'].astype(float)
    df['main.humidity'] = df['main.humidity'].astype(float)

    # Filtrar usando query
    query_result = df.query('name == "London" & `main.temp` < 15')
    print("\nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
    print(query_result)
else:
    print("Error en la solicitud:", response.status_code, response.text)
# Out:
# Últimas 5 filas del DataFrame:
#             dt                                            weather  visibility  \
# 35  1729123200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 36  1729134000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 37  1729144800  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 38  1729155600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 39  1729166400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
#
#      pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 35  1.00  2024-10-17 00:00:00      16.90            17.07          16.90
# 36  0.97  2024-10-17 03:00:00      17.22            17.37          17.22
# 37  0.54  2024-10-17 06:00:00      16.46            16.56          16.46
# 38  0.00  2024-10-17 09:00:00      16.72            16.67          16.72
# 39  0.00  2024-10-17 12:00:00      17.51            17.20          17.51
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 35          16.90           1005            1005             1001
# 36          17.22           1006            1006             1002
# 37          16.46           1008            1008             1004
# 38          16.72           1011            1011             1007
# 39          17.51           1013            1013             1008
#
#     main.humidity  main.temp_kf  clouds.all  wind.speed  wind.deg  wind.gust  \
# 35             93           0.0         100        4.09       157      12.19
# 36             91           0.0         100        5.12       177      10.95
# 37             92           0.0         100        4.04       197       9.13
# 38             85           0.0         100        3.24       230       6.59
# 39             72           0.0         100        3.42       240       5.17
#
#     rain.3h sys.pod
# 35     0.30       n
# 36     0.52       n
# 37     0.10       n
# 38      NaN       d
# 39      NaN       d
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dt               40 non-null     int64
#  1   weather          40 non-null     object
#  2   visibility       40 non-null     int64
#  3   pop              40 non-null     float64
#  4   dt_txt           40 non-null     object
#  5   main.temp        40 non-null     float64
#  6   main.feels_like  40 non-null     float64
#  7   main.temp_min    40 non-null     float64
#  8   main.temp_max    40 non-null     float64
#  9   main.pressure    40 non-null     int64
#  10  main.sea_level   40 non-null     int64
#  11  main.grnd_level  40 non-null     int64
#  12  main.humidity    40 non-null     int64
#  13  main.temp_kf     40 non-null     float64
#  14  clouds.all       40 non-null     int64
#  15  wind.speed       40 non-null     float64
#  16  wind.deg         40 non-null     int64
#  17  wind.gust        40 non-null     float64
#  18  rain.3h          9 non-null      float64
#  19  sys.pod          40 non-null     object
# dtypes: float64(9), int64(8), object(3)
# memory usage: 6.4+ KB
# None
#
# Estadísticas descriptivas del DataFrame:
#                  dt  visibility        pop  main.temp  main.feels_like  \
# count  4.000000e+01        40.0  40.000000  40.000000        40.000000
# mean   1.728956e+09     10000.0   0.194750  12.955750        12.229000
# std    1.262569e+05         0.0   0.374536   3.664807         4.354796
# min    1.728745e+09     10000.0   0.000000   6.540000         3.870000
# 25%    1.728850e+09     10000.0   0.000000   9.622500         8.707500
# 50%    1.728956e+09     10000.0   0.000000  12.550000        11.860000
# 75%    1.729061e+09     10000.0   0.057500  16.552500        16.565000
# max    1.729166e+09     10000.0   1.000000  20.660000        20.530000
#
#        main.temp_min  main.temp_max  main.pressure  main.sea_level  \
# count      40.000000      40.000000      40.000000       40.000000
# mean       12.883500      12.955750    1013.450000     1013.450000
# std         3.669519       3.664807       6.038127        6.038127
# min         6.540000       6.540000    1004.000000     1004.000000
# 25%         9.622500       9.622500    1007.000000     1007.000000
# 50%        12.305000      12.550000    1014.000000     1014.000000
# 75%        16.552500      16.552500    1019.250000     1019.250000
# max        20.660000      20.660000    1021.000000     1021.000000
#
#        main.grnd_level  main.humidity  main.temp_kf  clouds.all  wind.speed  \
# count         40.00000      40.000000     40.000000   40.000000   40.000000
# mean        1009.10000      75.375000      0.072250   94.775000    3.426750
# std            6.12184      11.258473      0.322303   16.727817    1.413092
# min         1000.00000      51.000000      0.000000   11.000000    0.900000
# 25%         1002.00000      66.750000      0.000000   99.000000    2.220000
# 50%         1009.50000      77.500000      0.000000  100.000000    3.405000
# 75%         1015.00000      83.250000      0.000000  100.000000    4.397500
# max         1017.00000      93.000000      1.650000  100.000000    6.230000
#
#          wind.deg  wind.gust   rain.3h
# count   40.000000  40.000000  9.000000
# mean   166.725000   8.056250  0.455556
# std     70.532767   3.715558  0.298208
# min     76.000000   1.160000  0.100000
# 25%    111.000000   4.982500  0.260000
# 50%    130.000000   9.105000  0.300000
# 75%    230.750000  11.255000  0.720000
# max    308.000000  13.190000  0.870000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[20], line 37
#      34 df['main.humidity'] = df['main.humidity'].astype(float)
#      36 # Filtrar usando query
# ---> 37 query_result = df.query('name == "London" & `main.temp` < 15')
#      38 print("\nFilas donde la ciudad es 'London' y la temperatura es menor a 15 grados Celsius:")
#      39 print(query_result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
#    4947 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4949 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:418, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     416     raise SyntaxError("only a single expression is allowed")
#     417 expr = node.body[0]
# --> 418 return self.visit(expr, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     420 def visit_Expr(self, node, **kwargs):
# --> 421     return self.visit(node.value, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:739, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
# --> 739     lhs = self._try_visit_binop(x)
#     740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:532, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     531 def visit_BinOp(self, node, **kwargs):
# --> 532     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533     left, right = self._maybe_downcast_constants(left, right)
#     534     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:452, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     450 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451     if left is None:
# --> 452         left = self.visit(node.left, side="left")
#     453     if right is None:
#     454         right = self.visit(node.right, side="right")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:412, in BaseExprVisitor.visit(self, node, **kwargs)
#     410 method = f"visit_{type(node).__name__}"
#     411 visitor = getattr(self, method)
# --> 412 return visitor(node, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'name' is not defined

# %%
# Paso 6: Slicing de Datos
city_temp = df[['dt', 'main.temp']]
print("nColumnas 'city' y 'temp':")
print(city_temp)

loc_result = df.loc[5:10, ['dt', 'weather']]
print("nFilas 5 a 10 y columnas 'name' y 'weather' usando loc:")
print(loc_result)

iloc_result = df.iloc[0:5, 0:3]
print("nPrimeras 5 filas y primeras 3 columnas usando iloc:")
print(iloc_result)
# Out:
# nColumnas 'city' y 'temp':
#             dt  main.temp
# 0   1728745200      14.14
# 1   1728756000      12.47
# 2   1728766800       8.91
# 3   1728777600       7.74
# 4   1728788400       7.08
# 5   1728799200       6.54
# 6   1728810000       8.10
# 7   1728820800       9.99
# 8   1728831600      10.32
# 9   1728842400       9.70
# 10  1728853200       9.19
# 11  1728864000       8.83
# 12  1728874800       8.81
# 13  1728885600       8.81
# 14  1728896400       9.39
# 15  1728907200      11.42
# 16  1728918000      12.63
# 17  1728928800      11.81
# 18  1728939600      11.63
# 19  1728950400      11.75
# 20  1728961200      12.01
# 21  1728972000      12.12
# 22  1728982800      13.68
# 23  1728993600      17.09
# 24  1729004400      16.50
# 25  1729015200      14.67
# 26  1729026000      14.83
# 27  1729036800      14.16
# 28  1729047600      14.17
# 29  1729058400      14.18
# 30  1729069200      16.71
# 31  1729080000      20.66
# 32  1729090800      18.00
# 33  1729101600      18.14
# 34  1729112400      17.24
# 35  1729123200      16.90
# 36  1729134000      17.22
# 37  1729144800      16.46
# 38  1729155600      16.72
# 39  1729166400      17.51
# nFilas 5 a 10 y columnas 'name' y 'weather' usando loc:
#             dt                                            weather
# 5   1728799200  [{'id': 804, 'main': 'Clouds', 'description': ...
# 6   1728810000  [{'id': 804, 'main': 'Clouds', 'description': ...
# 7   1728820800  [{'id': 804, 'main': 'Clouds', 'description': ...
# 8   1728831600  [{'id': 804, 'main': 'Clouds', 'description': ...
# 9   1728842400  [{'id': 804, 'main': 'Clouds', 'description': ...
# 10  1728853200  [{'id': 804, 'main': 'Clouds', 'description': ...
# nPrimeras 5 filas y primeras 3 columnas usando iloc:
#            dt                                            weather  visibility
# 0  1728745200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1  1728756000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2  1728766800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 3  1728777600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4  1728788400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000

# %%
loc_result = df.loc[5:10, ['dt', 'weather']]
print("nFilas 5 a 10 y columnas 'name' y 'weather' usando loc:")
print(loc_result)

iloc_result = df.iloc[0:5, 0:3]
print("nPrimeras 5 filas y primeras 3 columnas usando iloc:")
print(iloc_result)
# Out:
# nFilas 5 a 10 y columnas 'name' y 'weather' usando loc:
#             dt                                            weather
# 5   1728799200  [{'id': 804, 'main': 'Clouds', 'description': ...
# 6   1728810000  [{'id': 804, 'main': 'Clouds', 'description': ...
# 7   1728820800  [{'id': 804, 'main': 'Clouds', 'description': ...
# 8   1728831600  [{'id': 804, 'main': 'Clouds', 'description': ...
# 9   1728842400  [{'id': 804, 'main': 'Clouds', 'description': ...
# 10  1728853200  [{'id': 804, 'main': 'Clouds', 'description': ...
# nPrimeras 5 filas y primeras 3 columnas usando iloc:
#            dt                                            weather  visibility
# 0  1728745200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1  1728756000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2  1728766800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 3  1728777600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4  1728788400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000

# %%
iloc_result = df.iloc[0:5, 0:3]
print("nPrimeras 5 filas y primeras 3 columnas usando iloc:")
print(iloc_result)
# Out:
# nPrimeras 5 filas y primeras 3 columnas usando iloc:
#            dt                                            weather  visibility
# 0  1728745200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1  1728756000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2  1728766800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 3  1728777600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4  1728788400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000

# %%
print(df.columns)
# Out:
# Index(['dt', 'weather', 'visibility', 'pop', 'dt_txt', 'main.temp',
#        'main.feels_like', 'main.temp_min', 'main.temp_max', 'main.pressure',
#        'main.sea_level', 'main.grnd_level', 'main.humidity', 'main.temp_kf',
#        'clouds.all', 'wind.speed', 'wind.deg', 'wind.gust', 'rain.3h',
#        'sys.pod'],
#       dtype='object')

# %%
    # Seleccionar las primeras 5 filas y primeras 3 columnas usando iloc
    iloc_result = df.iloc[0:5, 0:3]
    print("\nPrimeras 5 filas y primeras 3 columnas usando iloc:")
    print(iloc_result)
# Out:
# Primeras 5 filas y primeras 3 columnas usando iloc:
#            dt                                            weather  visibility
# 0  1728745200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 1  1728756000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 2  1728766800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 3  1728777600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4  1728788400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
